# %%
#open the ein csv
ein_list=[42484464,201372435 ,630377461,831378576]

# %%
#import
import pandas as pd
#query

# %%
index_df=pd.read_csv("index_2022.csv",index_col=False)

# %%
index_df
#EIN 
#ObjectId = xml file
# Out:
#         RETURN_ID        EIN  TAX_PERIOD              SUB_DATE  \
# 0        19675507  562243027      202106   3/2/2022 7:14:38 AM
# 1        19675508  630377461      202108   3/2/2022 7:14:38 AM
# 2        19675509  471779282      202106   3/2/2022 7:14:38 AM
# 3        19675510  201372435      202106   3/2/2022 7:14:38 AM
# 4        19675511   42484464      202108   3/2/2022 7:14:38 AM
# ...           ...        ...         ...                   ...
# 118949   19583158  831378576      202108  1/31/2022 3:48:28 PM
# 118950   19678717  911212740      202106   3/2/2022 8:01:00 AM
# 118951   19678718  510145188      202106   3/2/2022 8:01:00 AM
# 118952   19678720  710876762      202103   3/2/2022 8:01:01 AM
# 118953   19678721  593575428      202106   3/2/2022 8:01:01 AM
#
#                                            TAXPAYER_NAME RETURN_TYPE  \
# 0                          CASA ESPERANZA MONTESSORI INC         990
# ...

# %%
#use the ein to search the index for file
empty_df= pd.DataFrame()
results=[]
for element in ein_list:
    test_query=index_df.where(index_df['EIN'] == element)
    result=test_query.dropna()
    #if results
    empty_df=pd.concat([empty_df,result])

# %%
empty_df
# Out:
#          RETURN_ID          EIN  TAX_PERIOD              SUB_DATE  \
# 4       19675511.0   42484464.0    202108.0   3/2/2022 7:14:38 AM
# 3       19675510.0  201372435.0    202106.0   3/2/2022 7:14:38 AM
# 1       19675508.0  630377461.0    202108.0   3/2/2022 7:14:38 AM
# 118949  19583158.0  831378576.0    202108.0  1/31/2022 3:48:28 PM
#
#                                    TAXPAYER_NAME RETURN_TYPE           DLN  \
# 4              CHILDRENS CENTER OF LEXINGTON INC         990  9.349304e+13
# 3       DELAWARE STATE UNIVERSITY FOUNDATION INC         990  9.349304e+13
# 1                        SOUTHEASTERN CONFERENCE         990  9.349304e+13
# 118949                  CHAPARRAL WRESTLING CLUB         990  9.349336e+13
#
#            OBJECT_ID
# 4       2.022104e+17
# 3       2.022104e+17
# 1       2.022104e+17
# 118949  2.021436e+17

# %%
xmllist=empty_df['OBJECT_ID'].drop_duplicates()

# %%
xmllist.to_list()
# Out:
# [2.0221040934930106e+17, 2.0221040934930102e+17, 2.0214357934930093e+17]

# %%
index_df.where(index_df['OBJECT_ID'] == empty_df['OBJECT_ID'][4]).dropna()
# Out:
#     RETURN_ID          EIN  TAX_PERIOD             SUB_DATE  \
# 3  19675510.0  201372435.0    202106.0  3/2/2022 7:14:38 AM
# 4  19675511.0   42484464.0    202108.0  3/2/2022 7:14:38 AM
#
#                               TAXPAYER_NAME RETURN_TYPE           DLN  \
# 3  DELAWARE STATE UNIVERSITY FOUNDATION INC         990  9.349304e+13
# 4         CHILDRENS CENTER OF LEXINGTON INC         990  9.349304e+13
#
#       OBJECT_ID
# 3  2.022104e+17
# 4  2.022104e+17
